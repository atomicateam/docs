# %% [markdown]
# # T2 - Calibration

# %%
import atomica as at
P = at.Project(framework='assets/t2_framework_1.xlsx',databook='assets/t2_databook_1.xlsx')
# Out:
# Atomica 1.18.1 (2020-02-02) -- (c) the Atomica development team
# git branch: Git branch N/A (Git hash)
# 2020-03-02 03:26:55.528211
# Initialization characteristics are underdetermined - this may be intentional, but check the initial compartment sizes carefully
# Elapsed time for running "default": 0.0112s

# %%
result = P.run_sim()
d = at.PlotData(result,project=P)
at.plot_series(d);
# Out:
# Elapsed time for running "default": 0.0131s

# %%
p2 = P.parsets[0].copy()
p2.pars['infx'].y_factor['adults'] = 5

# %%
r2 = P.run_sim(parset=p2,result_name = 'More infectious')
d = at.PlotData([result,r2],project=P)
at.plot_series(d,axis='results');
# Out:
# Elapsed time for running "default": 0.0134s
